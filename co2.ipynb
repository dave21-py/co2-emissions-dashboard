# %%
import numpy as np
import pandas as pd
import panel as pn
pn.extension('tabulator')
import hvplot.pandas
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='0191deae-a884-49c9-b74e-b8609b7f86b5'>
#   <div id="d5c757d4-098f-47fe-acf6-c7b0fe060ba1" data-root-id="0191deae-a884-49c9-b74e-b8609b7f86b5" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"28f563c4-c707-4c67-818e-fa2361d9f2f3":{"version":"3.7.3","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"0191deae-a884-49c9-b74e-b8609b7f86b5"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"18335111-261e-443e-90d7-78e66f927adb","attributes":{"plot_id":"0191deae-a884-49c9-b74e-b8609b7f86b5","comm_id":"ff05719f48484f21bdb50bfb848f48f5","client_comm_id":"5d5e933065fa43688a236eb00b72c9f2"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"ReactiveESM1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"JSComponent1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"ReactComponent1","properties":[{"name":"use_shadow_dom","kind":"Any","default":true},{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"AnyWidgetComponent1","properties":[{"name":"use_shadow_dom","kind":"Any","default":true},{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"max_notifications","kind":"Any","default":5},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_rendered","kind":"Any","default":false},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","defaul ...
#   var render_items = [{"docid":"28f563c4-c707-4c67-818e-fa2361d9f2f3","roots":{"0191deae-a884-49c9-b74e-b8609b7f86b5":"d5c757d4-098f-47fe-acf6-c7b0fe060ba1"},"root_ids":["0191deae-a884-49c9-b74e-b8609b7f86b5"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined && ( root.Tabulator !== undefined) && ( root.Tabulator !== undefined) && ( root.Tabulator !== undefined) && ( root.Tabulator !== undefined) && ( root.Tabulator !== undefined))
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
df = pd.read_csv('owid-co2-data.csv')
df
# Out:
#            country  year iso_code  population           gdp  cement_co2  \
# 0      Afghanistan  1750      AFG   2802560.0           NaN       0.000
# 1      Afghanistan  1751      AFG         NaN           NaN       0.000
# 2      Afghanistan  1752      AFG         NaN           NaN       0.000
# 3      Afghanistan  1753      AFG         NaN           NaN       0.000
# 4      Afghanistan  1754      AFG         NaN           NaN       0.000
# ...            ...   ...      ...         ...           ...         ...
# 50186     Zimbabwe  2019      ZWE  15271377.0  2.514642e+10       0.473
# 50187     Zimbabwe  2020      ZWE  15526888.0  2.317871e+10       0.496
# 50188     Zimbabwe  2021      ZWE  15797220.0  2.514009e+10       0.531
# 50189     Zimbabwe  2022      ZWE  16069061.0  2.590159e+10       0.531
# 50190     Zimbabwe  2023      ZWE  16340829.0           NaN       0.531
#
#        cement_co2_per_capita     co2  co2_growth_abs  co2_growth_prct  ...  \
# 0                      0.000     NaN             NaN              NaN  ...
# 1                        NaN     NaN             NaN              NaN  ...
# 2                        NaN     NaN             NaN              NaN  ...
# 3                        NaN     NaN             NaN              NaN  ...
# 4                        NaN     NaN             NaN              NaN  ...
# ...                      ...     ...             ...              ...  ...
# 50186                  0.031  10.263          -0.942           -8.411  ...
# 50187                  0.032   8.495          -1.768          -17.231  ...
# 50188                  0.034  10.204           1.709           20.120  ...
# 50189                  0.033  10.425           0.221            2.169  ...
# 50190                  0.032  11.164           0.739            7.090  ...
#
#        share_global_other_co2  share_of_temperature_change_from_ghg  \
# 0                         NaN                                   NaN
# 1                         NaN                                   NaN
# 2                         NaN                                   NaN
# 3                         NaN                                   NaN
# 4                         NaN                                   NaN
# ...                       ...                                   ...
# 50186                     NaN                                 0.106
# 50187                     NaN                                 0.105
# 50188                     NaN                                 0.104
# 50189                     NaN                                 0.103
# 50190                     NaN                                 0.102
#
#        temperature_change_from_ch4  temperature_change_from_co2  \
# 0                              NaN                          NaN
# 1                              NaN                          NaN
# 2                              NaN                          NaN
# 3                              NaN                          NaN
# 4                              NaN                          NaN
# ...                            ...                          ...
# 50186                        0.001                        0.001
# 50187                        0.001                        0.001
# 50188                        0.001                        0.001
# 50189                        0.001                        0.001
# 50190                        0.001                        0.001
#
#        temperature_change_from_ghg  temperature_change_from_n2o  total_ghg  \
# 0                              NaN                          NaN        NaN
# 1                              NaN                          NaN        NaN
# 2                              NaN                          NaN        NaN
# 3                              NaN                          NaN        NaN
# 4                              NaN                          NaN        NaN
# ...                            ...                          ...        ...
# 50186                        0.002                          0.0     34.348
# 50187                        0.002                          0.0     31.323
# 50188                        0.002                          0.0     33.549
# 50189                        0.002                          0.0     33.772
# 50190                        0.002                          0.0     33.955
#
#        total_ghg_excluding_lucf  trade_co2  trade_co2_share
# 0                           NaN        NaN              NaN
# 1                           NaN        NaN              NaN
# 2                           NaN        NaN              NaN
# 3                           NaN        NaN              NaN
# 4                           NaN        NaN              NaN
# ...                         ...        ...              ...
# 50186                    17.531     -0.027           -0.261
# 50187                    15.775      0.612            7.209
# 50188                    17.599      0.539            5.280
# 50189                    17.910      0.315            3.018
# 50190                    18.608        NaN              NaN
#
# [50191 rows x 79 columns]

# %%
df.columns
# Out:
# Index(['country', 'year', 'iso_code', 'population', 'gdp', 'cement_co2',
#        'cement_co2_per_capita', 'co2', 'co2_growth_abs', 'co2_growth_prct',
#        'co2_including_luc', 'co2_including_luc_growth_abs',
#        'co2_including_luc_growth_prct', 'co2_including_luc_per_capita',
#        'co2_including_luc_per_gdp', 'co2_including_luc_per_unit_energy',
#        'co2_per_capita', 'co2_per_gdp', 'co2_per_unit_energy', 'coal_co2',
#        'coal_co2_per_capita', 'consumption_co2', 'consumption_co2_per_capita',
#        'consumption_co2_per_gdp', 'cumulative_cement_co2', 'cumulative_co2',
#        'cumulative_co2_including_luc', 'cumulative_coal_co2',
#        'cumulative_flaring_co2', 'cumulative_gas_co2', 'cumulative_luc_co2',
#        'cumulative_oil_co2', 'cumulative_other_co2', 'energy_per_capita',
#        'energy_per_gdp', 'flaring_co2', 'flaring_co2_per_capita', 'gas_co2',
#        'gas_co2_per_capita', 'ghg_excluding_lucf_per_capita', 'ghg_per_capita',
#        'land_use_change_co2', 'land_use_change_co2_per_capita', 'methane',
#        'methane_per_capita', 'nitrous_oxide', 'nitrous_oxide_per_capita',
#        'oil_co2', 'oil_co2_per_capita', 'other_co2_per_capita',
#        'other_industry_co2', 'primary_energy_consumption',
#        'share_global_cement_co2', 'share_global_co2',
#        'share_global_co2_including_luc', 'share_global_coal_co2',
#        'share_global_cumulative_cement_co2', 'share_global_cumulative_co2',
#        'share_global_cumulative_co2_including_luc',
#        'share_global_cumulative_coal_co2',
#        'share_global_cumulative_flaring_co2',
#        'share_global_cumulative_gas_co2', 'share_global_cumulative_luc_co2',
#        'share_global_cumulative_oil_co2', 'share_global_cumulative_other_co2',
#        'share_global_flaring_co2', 'share_global_gas_co2',
#        'share_global_luc_co2', 'share_global_oil_co2',
#        'share_global_other_co2', 'share_of_temperature_change_from_ghg',
#        'temperature_change_from_ch4', 'temperature_change_from_co2',
#        'temperature_change_from_ghg', 'temperature_change_from_n2o',
#        'total_ghg', 'total_ghg_excluding_lucf', 'trade_co2',
#        'trade_co2_share'],
#       dtype='object')

# %%
df[df['country'] == 'World']
# Out:
#       country  year iso_code    population           gdp  cement_co2  \
# 49295   World  1750      NaN  7.532793e+08           NaN         NaN
# 49296   World  1751      NaN           NaN           NaN         NaN
# 49297   World  1752      NaN           NaN           NaN         NaN
# 49298   World  1753      NaN           NaN           NaN         NaN
# 49299   World  1754      NaN           NaN           NaN         NaN
# ...       ...   ...      ...           ...           ...         ...
# 49564   World  2019      NaN  7.811294e+09  1.221494e+14    1623.120
# 49565   World  2020      NaN  7.887001e+09  1.185900e+14    1638.271
# 49566   World  2021      NaN  7.954448e+09  1.260048e+14    1696.308
# 49567   World  2022      NaN  8.021407e+09  1.301126e+14    1601.124
# 49568   World  2023      NaN  8.091735e+09           NaN    1569.346
#
#        cement_co2_per_capita        co2  co2_growth_abs  co2_growth_prct  ...  \
# 49295                    NaN      9.306             NaN              NaN  ...
# 49296                    NaN      9.407           0.101            1.088  ...
# 49297                    NaN      9.505           0.098            1.041  ...
# 49298                    NaN      9.610           0.105            1.108  ...
# 49299                    NaN      9.734           0.123            1.281  ...
# ...                      ...        ...             ...              ...  ...
# 49564                  0.208  37104.273         373.850            1.018  ...
# 49565                  0.208  35126.527       -1977.750           -5.330  ...
# 49566                  0.213  36991.734        1865.208            5.310  ...
# 49567                  0.200  37293.836         302.100            0.817  ...
# 49568                  0.194  37791.570         497.738            1.335  ...
#
#        share_global_other_co2  share_of_temperature_change_from_ghg  \
# 49295                     NaN                                   NaN
# 49296                     NaN                                   NaN
# 49297                     NaN                                   NaN
# 49298                     NaN                                   NaN
# 49299                     NaN                                   NaN
# ...                       ...                                   ...
# 49564                   100.0                                 100.0
# 49565                   100.0                                 100.0
# 49566                   100.0                                 100.0
# 49567                   100.0                                 100.0
# 49568                   100.0                                 100.0
#
#        temperature_change_from_ch4  temperature_change_from_co2  \
# 49295                          NaN                          NaN
# 49296                          NaN                          NaN
# 49297                          NaN                          NaN
# 49298                          NaN                          NaN
# 49299                          NaN                          NaN
# ...                            ...                          ...
# 49564                        0.401                        1.090
# 49565                        0.406                        1.107
# 49566                        0.411                        1.125
# 49567                        0.417                        1.143
# 49568                        0.422                        1.161
#
#        temperature_change_from_ghg  temperature_change_from_n2o  total_ghg  \
# 49295                          NaN                          NaN        NaN
# 49296                          NaN                          NaN        NaN
# 49297                          NaN                          NaN        NaN
# 49298                          NaN                          NaN        NaN
# 49299                          NaN                          NaN        NaN
# ...                            ...                          ...        ...
# 49564                        1.571                        0.080  52796.523
# 49565                        1.595                        0.081  50792.543
# 49566                        1.619                        0.083  52938.793
# 49567                        1.644                        0.084  53327.215
# 49568                        1.668                        0.085  53816.852
#
#        total_ghg_excluding_lucf  trade_co2  trade_co2_share
# 49295                       NaN        NaN              NaN
# 49296                       NaN        NaN              NaN
# 49297                       NaN        NaN              NaN
# 49298                       NaN        NaN              NaN
# 49299                       NaN        NaN              NaN
# ...                         ...        ...              ...
# 49564                 43147.367      0.004              0.0
# 49565                 41394.840      0.000              0.0
# 49566                 43391.352      0.004              0.0
# 49567                 43746.762      0.004              0.0
# 49568                 44114.785     -0.004             -0.0
#
# [274 rows x 79 columns]

# %%
df = df.fillna(0)
df
# Out:
#            country  year iso_code  population           gdp  cement_co2  \
# 0      Afghanistan  1750      AFG   2802560.0  0.000000e+00       0.000
# 1      Afghanistan  1751      AFG         0.0  0.000000e+00       0.000
# 2      Afghanistan  1752      AFG         0.0  0.000000e+00       0.000
# 3      Afghanistan  1753      AFG         0.0  0.000000e+00       0.000
# 4      Afghanistan  1754      AFG         0.0  0.000000e+00       0.000
# ...            ...   ...      ...         ...           ...         ...
# 50186     Zimbabwe  2019      ZWE  15271377.0  2.514642e+10       0.473
# 50187     Zimbabwe  2020      ZWE  15526888.0  2.317871e+10       0.496
# 50188     Zimbabwe  2021      ZWE  15797220.0  2.514009e+10       0.531
# 50189     Zimbabwe  2022      ZWE  16069061.0  2.590159e+10       0.531
# 50190     Zimbabwe  2023      ZWE  16340829.0  0.000000e+00       0.531
#
#        cement_co2_per_capita     co2  co2_growth_abs  co2_growth_prct  ...  \
# 0                      0.000   0.000           0.000            0.000  ...
# 1                      0.000   0.000           0.000            0.000  ...
# 2                      0.000   0.000           0.000            0.000  ...
# 3                      0.000   0.000           0.000            0.000  ...
# 4                      0.000   0.000           0.000            0.000  ...
# ...                      ...     ...             ...              ...  ...
# 50186                  0.031  10.263          -0.942           -8.411  ...
# 50187                  0.032   8.495          -1.768          -17.231  ...
# 50188                  0.034  10.204           1.709           20.120  ...
# 50189                  0.033  10.425           0.221            2.169  ...
# 50190                  0.032  11.164           0.739            7.090  ...
#
#        share_global_other_co2  share_of_temperature_change_from_ghg  \
# 0                         0.0                                 0.000
# 1                         0.0                                 0.000
# 2                         0.0                                 0.000
# 3                         0.0                                 0.000
# 4                         0.0                                 0.000
# ...                       ...                                   ...
# 50186                     0.0                                 0.106
# 50187                     0.0                                 0.105
# 50188                     0.0                                 0.104
# 50189                     0.0                                 0.103
# 50190                     0.0                                 0.102
#
#        temperature_change_from_ch4  temperature_change_from_co2  \
# 0                            0.000                        0.000
# 1                            0.000                        0.000
# 2                            0.000                        0.000
# 3                            0.000                        0.000
# 4                            0.000                        0.000
# ...                            ...                          ...
# 50186                        0.001                        0.001
# 50187                        0.001                        0.001
# 50188                        0.001                        0.001
# 50189                        0.001                        0.001
# 50190                        0.001                        0.001
#
#        temperature_change_from_ghg  temperature_change_from_n2o  total_ghg  \
# 0                            0.000                          0.0      0.000
# 1                            0.000                          0.0      0.000
# 2                            0.000                          0.0      0.000
# 3                            0.000                          0.0      0.000
# 4                            0.000                          0.0      0.000
# ...                            ...                          ...        ...
# 50186                        0.002                          0.0     34.348
# 50187                        0.002                          0.0     31.323
# 50188                        0.002                          0.0     33.549
# 50189                        0.002                          0.0     33.772
# 50190                        0.002                          0.0     33.955
#
#        total_ghg_excluding_lucf  trade_co2  trade_co2_share
# 0                         0.000      0.000            0.000
# 1                         0.000      0.000            0.000
# 2                         0.000      0.000            0.000
# 3                         0.000      0.000            0.000
# 4                         0.000      0.000            0.000
# ...                         ...        ...              ...
# 50186                    17.531     -0.027           -0.261
# 50187                    15.775      0.612            7.209
# 50188                    17.599      0.539            5.280
# 50189                    17.910      0.315            3.018
# 50190                    18.608      0.000            0.000
#
# [50191 rows x 79 columns]

# %%
df['gdp_per_capita'] = np.where(df['population']!= 0, df['gdp']/df['population'],0)

# %%
idf = df.interactive()

# %%
#Slider
year_slider = pn.widgets.IntSlider(name='Year slider', start=1750, end=2020, step=5, value=1850)
year_slider
# Out:
# IntSlider(end=2020, name='Year slider', start=1750, step=5, value=1850)

# %%
#Radio Buttons for CO2 measures
yaxis_co2 = pn.widgets.RadioButtonGroup(
    name='Y axis',
    options=['co2', 'co2_per_capita',],
    button_type='success'
)

# %%
continents = ['World', 'Asia', 'Oceania', 'Europe', 'Africa', 'North America', 'South America', 'Antarctica']

co2_pipeline = (
    idf[
        (idf.year <= year_slider) &
        (idf.country.isin(continents))
    ]
    .groupby(['country', 'year']) [['co2', 'co2_per_capita']]
    .mean()
    .reset_index()
    .sort_values(by='year')  
    .reset_index(drop=True)
)

# %%
co2_pipeline
# Out:
# <div id='85cd6d83-059b-4de5-99f9-e5c81e99f2fc'>
#   <div id="fe1051db-6d5e-4735-bd69-0b91b2fe4155" data-root-id="85cd6d83-059b-4de5-99f9-e5c81e99f2fc" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"7ae2cde0-b4fc-4504-927e-86f3fb9977e0":{"version":"3.7.3","title":"Bokeh Application","roots":[{"type":"object","name":"Row","id":"85cd6d83-059b-4de5-99f9-e5c81e99f2fc","attributes":{"name":"Row83018","stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"e7735a3f-0514-4c08-84a5-210ccd353eed","attributes":{"url":"https://cdn.holoviz.org/panel/1.7.2/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"7a51b4c1-5bc5-4367-ae8b-9f05fef9670a","attributes":{"url":"https://cdn.holoviz.org/panel/1.7.2/dist/css/listpanel.css"}},{"type":"object","name":"ImportedStyleSheet","id":"01de4746-4372-456e-ac52-ef9b70aa814c","attributes":{"url":"https://cdn.holoviz.org/panel/1.7.2/dist/bundled/theme/default.css"}},{"type":"object","name":"ImportedStyleSheet","id":"6b485fc3-37dc-4972-bfb6-01e623eeea14","attributes":{"url":"https://cdn.holoviz.org/panel/1.7.2/dist/bundled/theme/native.css"}}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"c98676ca-1d5b-4bbf-a6e2-00d94a85a1d3","attributes":{"name":"Column83017","stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"id":"e7735a3f-0514-4c08-84a5-210ccd353eed"},{"id":"7a51b4c1-5bc5-4367-ae8b-9f05fef9670a"},{"id":"01de4746-4372-456e-ac52-ef9b70aa814c"},{"id":"6b485fc3-37dc-4972-bfb6-01e623eeea14"}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"2732eed5-d34b-4fdd-b4bd-214a1c3854ea","attributes":{"name":"Column83009","stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"id":"e7735a3f-0514-4c08-84a5-210ccd353eed"},{"id":"7a51b4c1-5bc5-4367-ae8b-9f05fef9670a"},{"id":"01de4746-4372-456e-ac52-ef9b70aa814c"},{"id":"6b485fc3-37dc-4972-bfb6-01e623eeea14"}],"margin":0,"align":"start","children":[{"type":"object","name":"Slider","id":"a96607e3-5b47-4f98-869c-17d9fb62c393","attributes":{"stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"id":"e7735a3f-0514-4c08-84a5-210ccd353eed"},{"id":"01de4746-4372-456e-ac52-ef9b70aa814c"},{"id":"6b485fc3-37dc-4972-bfb6-01e623eeea14"}],"margin":[5,10],"align":"start","title":"Year slider","start":1750,"end":2020,"value":1955,"step":5}}]}},{"type":"object","name":"panel.models.layout.Column","id":"25c9d58c-b6a9-445b-b8b8-be7c64229053","attributes":{"name":"Column83014","stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"id":"e7735a3f-0514-4c08-84a5-210ccd353eed"},{"id":"7a51b4c1-5bc5-4367-ae8b-9f05fef9670a"},{"id":"01de4746-4372-456e-ac52-ef9b70aa814c"},{"id":"6b485fc3-37dc-4972-bfb6-01e623eeea14"}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.markup.HTML","id":"173703f2-bb01-4fe9-b45c-99414e72e956","attributes":{"stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"id":"e7735a3f-0514-4c08-84a5-210ccd353eed"},{"type":"object","name":"ImportedStyleSheet","id":"0a52ef80-29c2-4099-a873-56d442903c5c","attributes":{"url":"https://cdn.holoviz.org/panel/1.7.2/dist/css/dataframe.css"}},{"id":"01de4746-4372-456e-ac52-ef9b70aa814c"},{"id":"6b485fc3-37dc-4972-bfb6-01e623eeea14"}],"margin":[5,10],"align":"start","text":"&lt;table class=&quot;da ...

# %%
co2_plot = co2_pipeline.hvplot(x = 'year', by='country', y=yaxis_co2.value,line_width=2, title="CO2 emission by continent")
co2_plot
# Out:
# Traceback (most recent call last):</br>
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/holoviews/plotting/util.py", line 305, in get_plot_frame</br>
#     return map_obj[key]</br>
#            ~~~~~~~^^^^^</br>
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/holoviews/core/spaces.py", line 1302, in __getitem__</br>
#     val = self._execute_callback(*tuple_key)</br>
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^</br>
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/holoviews/core/spaces.py", line 1050, in _execute_callback</br>
#     retval = self.callback(*args, **kwargs)</br>
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^</br>
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/holoviews/core/spaces.py", line 626, in __call__</br>
#     ret = self.callable(*args, **kwargs)</br>
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^</br>
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/param/depends.py", line 85, in _depends</br>
#     return func(*args, **kw)</br>
#            ^^^^^^^^^^^^^^^^^</br>
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/hvplot/interactive.py", line 384, in evaluate</br>
#     return evaluate_inner()</br>
#            ^^^^^^^^^^^^^^^^</br>
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/hvplot/interactive.py", line 374, in evaluate_inner</br>
#     obj = self.eval()</br>
#           ^^^^^^^^^^^</br>
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/hvplot/interactive.py", line 768, in eval</br>
#     obj = transform.apply(ds, keep_index=True, compute=False)</br>
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^</br>
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/holoviews/util/transform.py", line 800, in apply</br>
#     data = self._apply_fn(dataset, data, fn, fn_name, args,</br>
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^</br>
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/holoviews/util/transform.py", line 686, in _apply_fn</br>
#     raise e</br>
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/holoviews/util/transform.py", line 680, in _apply_fn</br>
#     data = method(*args, **kwargs)</br>
#            ^^^^^^^^^^^^^^^^^^^^^^^</br>
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/hvplot/plotting/core.py", line 95, in __call__</br>
#     return self._get_converter(x, y, kind, **kwds)(kind, x, y)</br>
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^</br>
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/hvplot/converter.py", line 1907, in __call__</br>
#     obj = method(x, y)</br>
#           ^^^^^^^^^^^^</br>
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/hvplot/converter.py", line 2431, in line</br>
#     return self.chart(Curve, x, y, data)</br>
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^</br>
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/hvplot/converter.py", line 2388, in chart</br>
#     return self.single_chart(element, x, y, data)</br>
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^</br>
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/hvplot/converter.py", line 2256, in single_chart</br>
#     Dataset(data, self.by + kdims, vdims).to(element, kdims, vdims, self.by),</br>
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^</br>
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/holoviews/core/data/__init__.py", line 338, in __init__</br>
#     self.interface.validate(self, validate_vdims)</br>
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/holoviews/core/data/pandas.py", line 201, in validate</br>
#     raise DataError("Supplied data does not contain specified "</br>
# holoviews.core.data.interface.DataError: Supplied data does not contain specified dimensions, the following dimensions were not found: ['co2']</br>
# </br>
# PandasInterface expects tabular data, for more information on supported datatypes see https://holoviews.org/user_guide/Tabular_Datasets.html</br>
# </br>
# Traceback (most recent call last):</br>
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/holoviews/plotting/util.py", line 305, in get_plot_frame</br>
#     return map_obj[key]</br>
#            ~~~~~~~^^^^^</br>
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/holoviews/core/spaces.py", line 1302, in __getitem__</br>
#     val = self._execute_callback(*tuple_key)</br>
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^</br>
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/holoviews/core/spaces.py", line 1050, in _execute_callback</br>
#     retval = self.callback(*args, **kwargs)</br>
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^</br>
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/holoviews/core/spaces.py", line 626, in __call__</br>
#     ret = self.callable(*args, **kwargs)</br>
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^</br>
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/param/depends.py", line 85, in _depends</br>
#     return func(*args, **kw)</br>
#            ^^^^^^^^^^^^^^^^^</br>
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/hvplot/interactive.py", line 384, in evaluate</br>
#     return evaluate_inner()</br>
#            ^^^^^^^^^^^^^^^^</br>
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/hvplot/interactive.py", line 374, in evaluate_inner</br>
#     obj = self.eval()</br>
#           ^^^^^^^^^^^</br>
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/hvplot/interactive.py", line 768, in eval</br>
#     obj = transform.apply(ds, keep_index=True, compute=False)</br>
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^</br>
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/holoviews/util/transform.py", line 800, in apply</br>
#     data = self._apply_fn(dataset, data, fn, fn_name, args,</br>
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^</br>
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/holoviews/util/transform.py", line 686, in _apply_fn</br>
#     raise e</br>
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/holoviews/util/transform.py", line 680, in _apply_fn</br>
#     data = method(*args, **kwargs)</br>
#            ^^^^^^^^^^^^^^^^^^^^^^^</br>
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/hvplot/plotting/core.py", line 95, in __call__</br>
#     return self._get_converter(x, y, kind, **kwds)(kind, x, y)</br>
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^</br>
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/hvplot/converter.py", line 1907, in __call__</br>
#     obj = method(x, y)</br>
#           ^^^^^^^^^^^^</br>
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/hvplot/converter.py", line 2431, in line</br>
#     return self.chart(Curve, x, y, data)</br>
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^</br>
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/hvplot/converter.py", line 2388, in chart</br>
#     return self.single_chart(element, x, y, data)</br>
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^</br>
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/hvplot
# <div id='d15dd4b1-98f4-4f80-b937-52c6a0ea42fc'>
#   <div id="d3b0ead7-5cbf-4285-a406-a3a7d7354574" data-root-id="d15dd4b1-98f4-4f80-b937-52c6a0ea42fc" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"2c8d8581-6b82-42d7-9677-ef4ab29c41ac":{"version":"3.7.3","title":"Bokeh Application","roots":[{"type":"object","name":"Row","id":"d15dd4b1-98f4-4f80-b937-52c6a0ea42fc","attributes":{"name":"Row83288","stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"5a7364e6-60a8-4b71-88a6-a71fd27d165d","attributes":{"url":"https://cdn.holoviz.org/panel/1.7.2/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"b784a11a-3932-4831-ad20-6036f18e5245","attributes":{"url":"https://cdn.holoviz.org/panel/1.7.2/dist/css/listpanel.css"}},{"type":"object","name":"ImportedStyleSheet","id":"a86f2945-1a4e-4f36-b04d-63186035ed08","attributes":{"url":"https://cdn.holoviz.org/panel/1.7.2/dist/bundled/theme/default.css"}},{"type":"object","name":"ImportedStyleSheet","id":"db71a0bb-bb02-41aa-af43-df4cc7d5e3b1","attributes":{"url":"https://cdn.holoviz.org/panel/1.7.2/dist/bundled/theme/native.css"}}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"2f0b92ce-4a8f-45a9-ae3d-c9dbc2baecd8","attributes":{"name":"Column83282","stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"id":"5a7364e6-60a8-4b71-88a6-a71fd27d165d"},{"id":"b784a11a-3932-4831-ad20-6036f18e5245"},{"id":"a86f2945-1a4e-4f36-b04d-63186035ed08"},{"id":"db71a0bb-bb02-41aa-af43-df4cc7d5e3b1"}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"07752a5c-3766-42bf-80a0-ca096d96c964","attributes":{"name":"Column83278","stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"id":"5a7364e6-60a8-4b71-88a6-a71fd27d165d"},{"id":"b784a11a-3932-4831-ad20-6036f18e5245"},{"id":"a86f2945-1a4e-4f36-b04d-63186035ed08"},{"id":"db71a0bb-bb02-41aa-af43-df4cc7d5e3b1"}],"margin":0,"align":"start","children":[{"type":"object","name":"Slider","id":"d095caa7-81dd-446b-9333-0ea6ebaf6ecb","attributes":{"stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"id":"5a7364e6-60a8-4b71-88a6-a71fd27d165d"},{"id":"a86f2945-1a4e-4f36-b04d-63186035ed08"},{"id":"db71a0bb-bb02-41aa-af43-df4cc7d5e3b1"}],"margin":[5,10],"align":"start","title":"Year slider","start":1750,"end":2020,"value":1955,"step":5}}]}},{"type":"object","name":"Figure","id":"3f155d5c-5ad2-458d-88c2-53420341e6dc","attributes":{"width":700,"height":300,"margin":[5,10],"sizing_mode":"fixed","align":"start","x_range":{"type":"object","name":"Range1d","id":"35582884-ce27-4efa-a82e-5b57f1ca5610","attributes":{"name":"year","tags":[[["year",null]],[]],"start":1750.0,"end":1955.0,"reset_start":1750.0,"reset_end":1955.0}},"y_range":{"type":"object","name":"Range1d","id":"5cd640db-9dbe-4502-a785-3699fbc8d002","attributes":{"name":"co2_per_capita","tags":[[["co2_per_capita",null]],{"type":"map","entries":[["invert_yaxis",false],["autorange",false]]}],"start":-1.4071,"end":15.4781,"reset_start":-1.4071,"reset_end":15.4781}},"x_scale":{"type":"object","name":"LinearScale","id":"0dea1d39-0af3-4a73-aed7-268e6e479631"},"y_scale":{"type":"object","name":"LinearScale","id":"5f603350-b592-45d8-8796-cc40a5475fec"},"title":{"type":"object","name":"Title","id":"5ead2898-6c01-4280-a111-76917056fe09","attributes":{"text":"CO2 emission by continent","text_color":"black","text_font_size":"12pt"}},"renderers":[{"type":"object","name":"GlyphRenderer","id":"e8983e52-9315-4485-961f-1721e8114a93","attributes":{"name":"Africa","data_source":{"type":"object","name":"Col ...
